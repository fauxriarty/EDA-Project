# %% [markdown]
# <a href="https://colab.research.google.com/github/fauxriarty/EDA-Project/blob/main/22BDS0179_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Course Project for EDA
# ## Aditya Chheda
# ## Reg. No: 22BDS0179
#
# Develop a model for the below dataset using Python Code (Colab)
#
#
# Dataset Link: https://raw.githubusercontent.com/salemprakash/EDA/main/Data/bank.csv

# %% [markdown]
# Instructions for Project Submission – BCSE331L (EDA)
#
# ● Create a GitHub account and connect it to your personal Google Colab interface.
# (Google Colab → Save a copy in GitHub → RollNo.ipynb)
#
# ● Load the dataset and explore the following:
#
# Dimensions
#
# Summary Statistics
#
# Data Handling
#
# Data Cleaning
#
# Univariate, Bivariate, and Multivariate Analysis
# (include all possible visualizations)
#
# ● Complete your tasks in parallel with the Theory Sessions (from Module 2 to Module 7).
#
# ● To understand more about the dataset attributes, you may refer to reliable sources on the web.
#
# Submission Details:
#
# ● Phase I: Submit your GitHub link via the Google Form by 15th Aug 2025.
# (5 marks – Evaluation will be conducted on 16th Aug 2025 - till Multivariate Analysis)
#
# ● Phase II: Completion of code till Module 5 in github
# (5 marks - Evaluation will be conducted on 2nd October - till Module 5)
#
# ● Phase III: Completion of full project in github and upload in VTop along with the report
# as a single document (Module 2 to Module 7).
# (5 marks - Evaluation will be conducted on 10th Nov and 5 marks - Evaluation for report
# completion)

# %%
import pandas as pd

# 1. Load the Dataset
url = 'https://raw.githubusercontent.com/salemprakash/EDA/main/Data/bank.csv'


try:
    df = pd.read_csv(url)
    print("✅ Dataset loaded successfully!")
    # Display the first 5 rows of the dataframe to verify the data has been loaded correctly
    print("\nFirst 5 rows of the dataset:")
    display(df.head())
except Exception as e:
    print(f"Error loading dataset: {e}")


# 2. Explore the Dimensions of the Dataset
# The .shape attribute returns a tuple representing the dimensionality (rows, columns)
print("\nDimensions of the dataset: ")
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")


# 3. Explore Summary Statistics
# The .info() method provides a concise summary of the DataFrame.
print("\nDataset Info: ")
df.info()

# The .describe() method generates descriptive statistics for the numerical columns.
# This includes count, mean, standard deviation, min/max, and quartile values.
print("\nSummary Statistics: ")
display(df.describe())
# Out:
# ✅ Dataset loaded successfully!
#
# First 5 rows of the dataset:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
# Dimensions of the dataset:
# ...
